# %% [markdown]
# # Assessed Activity: Distribution and Impact of Mutations in Human Genes
#
# Tasdasdasdhis notebook is the basis for the assessed activity of Unit 4 of the Introduction to Biology and Programming course. It will set out the tasks you need to complete and provide code to get you started. It is similar to the notebooks you've worked through in previous units. However, it will only provide outlines to the problems rather than individual steps to reach a solution. This means you will have more freedom in how you complete each task!
#
# As you work through the notebook, you can add any number of cells you wish. However, do make sure that you give your numerical answers in the appropriate cells and provide the functions requested as this will be what you are assessed on. Don't make other changes to these cells as this could affect your overall assessment.
#
# As with the previous notebooks, please run the following cell to import some functions that will help you in the assessment:

# %%
from unit_4_library import *

# %% [markdown]
# ## Reminder of Good Coding Practice
#
# Though you've now had a few weeks experience with coding, it's always good to be reminded of the methods that will help when tackling these assignements. As a final reminder, here are a few things to keep in mind:
#
# 1. Only make **small** additions and changes to your code. Don't type in many lines in one go.
# 2. Try to understand each bit of code you add and what it's doing. This will help with debugging.
# 3. Test everything often. After you've added a few (1-3) lines, **test them** so you are sure they work. This means that the output is correct as well as it running without errors.
# 4. Check error messages. Python is very good at telling you where and what the problem is so read them carefully.
#
# There is also one thing you **shouldn't** do: Don't resort to copying and pasting code from the internet that you don't understand. This will almost **never** help you and will actually make things a lot harder. Just focus on each little step of each part of the assignment in turn using the comments as a guide. They can all be solved using the methods and code presented in the course.
#
# Finally, progamming is a slow, logical and above all **iterative** process. Things **will** go wrong and often. If you hit an error, just go back over the code you've just added to look for problems.
#
#
# The below diagram will hopefully emphasise how the 'programming loop' works:
#
# ![programming_graphic.png](attachment:programming_graphic.png)

# %% [markdown]
# ## Important Note
#
# It's important to try to have your notebook run as intended from a clean Jupyter Session. Do try to check your notebook before submission to make sure it runs from top to bottom without any errors. To do this, use the menu option `'Kernel'->'Restart and Run All'` and check no errors are producd.

# %% [markdown]
# ## Task 1 - Investigating an Existing Dataset (16%)
#
# The first task is to investigate the frequency of different types of mutation in the Human Beta Globin Gene (HBB), which you have already worked with in Unit 3. Provided in this directory are the base sequence of the wild type (`wildtype.txt`) and 200 different mutated versions (`mutation_*.txt`). These files just include the basic DNA sequence without any header info to make things easier.
#
# For this assessment, can you:
#
#  1. Write a function `dna_comparison` that takes two **string (not filename)** arguments, the wild type sequence and a single mutated sequence, compares them and returns the number of transitions and transversions between the two in a list or tuple **in that order** (see **Important Info** below).
#  2. Your function should check for the following issues and if found, return zero transitions and transversions as well as printing an error message:
#      * The two DNA sequences being different lengths
#      * Characters not representing a DNA base
#  3. Use this function to investigate the population of mutations and give the **total** number of transitions and transversions across all the 200 files
#  4. Write a function `protein_comparison` that takes two **string (not filename)** arguments, the protein string of the wild type and the protein string of a single mutated sequence, compares them and returns the number of silent, missense and nonsense mutations between the two in a list or tuple **in that order** (see **Important Info** below).
#  5. Make sure your function checks for unknown characters in the protein string and if found, returns zero mutations and prints an error.
#  6. As before, Use this function to investigate the population of mutations and return the **total** number of silent, missense and nonsense mutations across all the 200 files
#
# Note these stages are also included as comments in the cell below to help you structure your code. You should be aiming for only a few lines of code for each comment.
#
# ### Important Info
#  * **There is a provided function to generate the protein string from a DNA sequence**. The `create_protein_string` function (imported above) takes an HBB dna string and returns the protein string.
#  * To find differences between two strings of equal length, loop using an index and compare each letter in turn.
#  * You can use the `glob` module to find all files that match a given wildcard string:
# ```
# In [1]: import glob
# In [2]: glob.glob("*.txt")
# Out[2]: ['lactase_gene.txt', 'TheRaven.txt']
# ```
#  * To return multiple values from a function you can provide a comma separated list:
#  ```
#  def myfunc():
#      return 1, 2.6, "a"
#
#  myint, myfloat, mystring = myfunc()
# ```
# * As you are dealing with SNP mutations, the total of transitions+transversions and silent+missense+nonsense should both equal 200

# %%
# Define a 'dna_comparison' function that takes two arguments (the wildtype and mutated sequences as strings)
    
    # Check if the two sequences are the same size
    
    # Using a 'for' loop, check each sequence for non-DNA characters
    
    # Create two variables to store the number of transitions and transversions
    
    # Write a 'for' loop with a loop variable that iterates from 0 to the length of the DNA sequences
    
        # Using the loop variable as the index, compare the bases for the current iteration between the two DNA strings
        
            # if they're different, decide on the type of mutation using conditionals and increase the appropriate variable

    # return the number of each type of mutation found
    
    
#-------------------------
# load the contents of the wildtype DNA sequence file (wildtype.txt) into a variable

# create variables to store the number of transitions and transversions

# Create a list of all the mutation files using the 'glob' library

# Write a 'for' loop that iterates over each mutation file in this list

    # load the mutated DNA sequence pointed at by the loop variable
    
    # Call the 'dna_comparison' function to find the mutation types between this and the wildtype
    
    # Add to the total number of transitions and transversions
    
    
#-------------------------
# Define a 'protein_comparison' function that takes two arguments (the wildtype and mutated protein sequences as strings)
    
    # Create three variables to store the number of silent missense and nonsense mutations
    
    # Using a 'for' loop, check each sequence for non-protein characters
    
    # compare the protein strings and decide on the type of mutation
    
    # return the number of each type of mutations found
    
    
#-------------------------
# create the protein string for the wildtype DNA sequence using the 'create_protein_string' function

# create variables to store the number of silent, missense and nonsense mutations

# Write a 'for' loop that iterates over each mutation file in the mutated DNA file list used previously

    # load the mutated DNA sequence pointed at by the loop variable

    # create and store the mutated protein sequence from this DNA sequence using 'create_protein_string' 
    
    # find the mutation type between this and the wildtype using the 'protein_comparison' function
    
    # Add to the total number of silent, missense and nonsense mutations

# %%
# this will only check the required functions exist, not if they do what is required!
check_answers_task1(dna_comparison, protein_comparison)

# complete the numerical answers here
task1_num_transitions_total = 
task1_num_transversions_total = 

task1_num_silent_total = 
task1_num_missense_total = 
task1_num_nonsense_total =

# %% [markdown]
# ## Task 2 - Simulating Random SNP Mutations (12%)
#
# The second task is to use the information you gained from analysing the 200 mutations to simulate your own batch of mutations. For this part of the assessment, can you:
#
#  1. Write a function `mutation_dna` that takes three arguments: the wild type gene sequence **as a string (not a filename)**, the index of the mutation and whether it should be a transition (`0` as an `int`) or transversion (`1` as an `int`) mutation. It should return the sequence with the requested Single Nucleotide Polymorphism (SNP) mutation applied.
#  2. Your function should check for the following issues and if found, return an empty string as well as printing an error message:
#    * Characters in the DNA string that aren't a base
#    * The given index is out of range
#    * Giving a number other than `0` or `1` for the mutation type
#  3. Create another function `generate_mutations` that takes the wild type gene and the number of sequences to generate. It should return the requested number of mutated DNA sequences in a list. These SNP mutations should be:
#    * Uniform across the DNA sequence, i.e. the mutation should have an equal chance of occuring at any index in the gene sequence
#    * Have the probability of transition and transversion be the same as what was found in Task 1
#  4. Using your function, generate a population of 500 mutated DNA sequences. Using this new dataset, redo your analysis from Task 1 and provide your results.
#
# ### Important Info
#  * From the `random` module, use the `random.random()` function with a conditional to decide something given a specific decimal probability:
# ```
#    if random.random() < 0.3:
#       print("This will happen 30% of the time")
# ```
#  * Use the `random.randrange` function to select a random integer from the first value up to (but not including!) the second integer given
#  ```
# In [2]: random.randrange(0, 7)
# Out[2]: 3
# ```
#   * Use `random.choice` to randomly select a value from a list of possible ones
# ```
# In [2]: random.choice(['a', 'b', 'c'])
# Out[2]: 'c'
# ```

# %%
# -------------------
# Define a 'mutation_dna' function that takes three arguments (wildtype DNA sequence, index and mutation type)
    
    # Check all the characters in the string are DNA bases
    
    # Check if the index is out of range
    
    # Check a 0 or 1 has been given for the index type
    
    # find the DNA base at the requested index
    
    # If the type of mutation requested is a transition, identify the base it will change to
    
    # If the type of mutation requested is a transversion, randomly decide which base it will change to (50% probability for each option)
    
    # construct the new DNA string using the mutated base decided above
    
    # return the new DNA string
    
# -------------------    
# Define a 'generate_mutations' function that takes two arguments (wildtype DNA sequence and number of sequences to generate)

    # Create an empty list to store the mutated strings
    
    # Write a 'for' loop that iterates from 0 to the requested number of mutations
        
        # randomly generate the index position for the mutation
        
        # decide if it should be a transition or transversion using your frequency from Task 1
        
        # Use this info to call your mutation_dna function to create the mutated sequence
        
        # Add this to the list
        
    # return the list of mutated DNA strings
    
# -------------------    
# generate 500 mutated DNA sequences

# redo Task 1 analysis on this population

# %%
# this will only check the required functions exist, not if they do what is required!
check_answers_task2(mutation_dna, generate_mutations)

# Values from your 500 generated mutations
task2_num_transitions_total = 
task2_num_transversions_total = 

task2_num_silent_total = 
task2_num_missense_total = 
task2_num_nonsense_total =
